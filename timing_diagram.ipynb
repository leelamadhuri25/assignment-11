# %%
# importing required modules 
import matplotlib.pyplot as plt 
import numpy as np 

# setting a style to use 
plt.style.use('ggplot') 

# create a figure 
fig = plt.figure(figsize=(12, 15)) 

# define subplots and their positions in figure 
# x axis values 
x = [None] * 201
x[0] = 0
j = 0.5
for i in range(1,100,2):
  x[i] = j
  x[i+1] = j
  j = j+0.5
y = [None]*201
j = 0
for i in range(0,60,4):
  y[i] = 0
  y[i+1] = 0
  y[i+2] = 1
  y[i+3] = 1
plt2 = fig.add_subplot(511) 
plt2.plot(x, y, color ='b') 
plt2.set_title('Timing Diagram for $Clk$') 
plt.xlabel('Time') 
plt.ylabel('Output') 
plt.ylim(-0.1,1.7) 
plt.xlim(-0.1,12.3) 

x = [None] * 201
x[0] = 0
j = 1
for i in range(1,100,2):
  x[i] = j
  x[i+1] = j
  j = j+1
y = [None]*201
j = 0
for i in range(0,60,4):
  y[i] = 0
  y[i+1] = 0
  y[i+2] = 1
  y[i+3] = 1
plt1 = fig.add_subplot(512) 
plt1.plot(x, y, color ='r') 
plt1.set_title('Timing Diagram for D$_3$') 
plt.xlabel('Time') 
plt.ylabel('Output at $Q_3$') 
plt.ylim(-0.1,1.7) 
plt.xlim(-0.1,12.3) 

x = [None] * 201
x[0] = 0
j = 2
for i in range(1,100,2):
  x[i] = j
  x[i+1] = j
  j = j+2
y = [None]*201
j = 0
for i in range(0,60,4):
  y[i] = 0
  y[i+1] = 0
  y[i+2] = 1
  y[i+3] = 1
plt2 = fig.add_subplot(513) 
plt2.plot(x, y, color ='b') 
plt2.set_title('Timing Diagram for D$_5$') 
plt.xlabel('Time') 
plt.ylabel('Output at $Q_5$') 
plt.ylim(-0.1,1.7) 
plt.xlim(-0.1,12.3) 

x = [None] * 201
x[0] = 0
j = 4
for i in range(1,100,2):
  x[i] = j
  x[i+1] = j
  j = j+4
y = [None]*201
j = 0
for i in range(0,60,4):
  y[i] = 0
  y[i+1] = 0
  y[i+2] = 1
  y[i+3] = 1
plt3 = fig.add_subplot(514) 
plt3.plot(x, y, color ='g') 
plt3.set_title('Timing Diagram for $Y=Q_3+Q_5$') 
plt.xlabel('Time') 
plt.ylabel('Voltage at $Y$ (A=5V)') 
plt.ylim(-0.1,1.7) 
plt.xlim(-0.1,12.3) 

x = [None] * 201
x[0] = 0
j = 8
for i in range(1,100,2):
  x[i] = j
  x[i+1] = j
  j = j+8
y = [None]*201
j = 0
for i in range(0,60,4):
  y[i] = 0
  y[i+1] = 0
  y[i+2] = 1
  y[i+3] = 1
plt3 = fig.add_subplot(515) 
plt3.plot(x, y, color ='g') 
plt3.set_title('Timing Diagram for $Y=Q_3+Q_5$') 
plt.xlabel('Time') 
plt.ylabel('Voltage at $Y$ (A=5V)') 
plt.ylim(-0.1,1.7) 
plt.xlim(-0.1,12.3) 

fig.subplots_adjust(hspace=.5)
plt.savefig('graph.pdf')
# function to show the plot 
plt.show()
